# %%
import pandas as pd

# %% [markdown]
# -    creating dataset
#      -   dictionary of items
#      -   list of dictionary
# -    get basic insights
# -    data selection
#       -   row wise selection
#      -   column wise selection
# -    data cleaning and manipulation

# %%
movies={
    'title':['Inception', 'The Mtrix', 'intersteller'],
    'year':[2010, 1999, 2014],
    'rating':[8.8, 8.7, 8.6],
    'genre':['Sci-Fi', 'Sci-Fi', 'Sci-Fi'],
}
df=pd.DataFrame(movies)
df
# Out:
#           title  year  rating   genre
# 0     Inception  2010     8.8  Sci-Fi
# 1     The Mtrix  1999     8.7  Sci-Fi
# 2  intersteller  2014     8.6  Sci-Fi

# %%
import pandas as pd

movies = [
    {'title': 'Inception', 'year': 2020, 'rating': 6.6, 'genre': 'Sci-Fi'},
    {'title': 'the matrix', 'year': 1999, 'rating': 2.2, 'genre': 'Sci-Fi'},
    {'title': 'Intersteller', 'year': 2014, 'rating': 8.6, 'genre': 'Sci-Fi'}
]

df = pd.DataFrame(movies)
print(df)
# Out:
#           title  year  rating   genre
# 0     Inception  2020     6.6  Sci-Fi
# 1    the matrix  1999     2.2  Sci-Fi
# 2  Intersteller  2014     8.6  Sci-Fi

# %%
df=pd.read_csv('kc_house_data (2).csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head() # display the first five rows by default
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.sample()
# Out:
#               id             date     price  bedrooms  bathrooms  sqft_living  \
# 4487  4137000110  20140725T000000  340000.0         3        2.5         2270
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4487      7917     2.0           0     0  ...      8        2270
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat    long  \
# 4487              0      1986             0    98092  47.2643 -122.22
#
#       sqft_living15  sqft_lot15
# 4487           2160        7917
#
# [1 rows x 21 columns]

# %%
df.shape
# Out:
# (21613, 21)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# -   row wise selection
#     - iloc - index based selection
#     - loc - label based selection
# - column wise selection
#     - single column selection
#         - dictionary like selection
#         - object like selection
#     -   multiple columns selection
#         - dictionary like selection

# %%
df.iloc[2]
# Out:
# id                    5631500400
# date             20150225T000000
# price                   180000.0
# bedrooms                       2
# bathrooms                    1.0
# sqft_living                  770
# sqft_lot                   10000
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          6
# sqft_above                   770
# sqft_basement                  0
# yr_built                    1933
# yr_renovated                   0
# zipcode                    98028
# lat                      47.7379
# long                    -122.233
# sqft_living15               2720
# sqft_lot15                  8062
# Name: 2, dtype: object

# %%
df.iloc[-3]
# Out:
# id                    1523300141
# date             20140623T000000
# price                   402101.0
# bedrooms                       2
# bathrooms                   0.75
# sqft_living                 1020
# sqft_lot                    1350
# floors                       2.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          7
# sqft_above                  1020
# sqft_basement                  0
# yr_built                    2009
# yr_renovated                   0
# zipcode                    98144
# lat                      47.5944
# long                    -122.299
# sqft_living15               1020
# sqft_lot15                  2007
# Name: 21610, dtype: object

# %%
df.iloc[2:6]
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 2  5631500400  20150225T000000   180000.0         2        1.0          770
# 3  2487200875  20141209T000000   604000.0         4        3.0         1960
# 4  1954400510  20150218T000000   510000.0         3        2.0         1680
# 5  7237550310  20140512T000000  1225000.0         4        4.5         5420
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 2      1933             0    98028  47.7379 -122.233           2720
# ...

# %%
 df.iloc[[3,5,9,11]]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 3   2487200875  20141209T000000   604000.0         4        3.0         1960
# 5   7237550310  20140512T000000  1225000.0         4        4.5         5420
# 9   3793500160  20150312T000000   323000.0         3        2.5         1890
# 11  9212900260  20140527T000000   468000.0         2        1.0         1160
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3       5000     1.0           0     0  ...      7        1050            910
# 5     101930     1.0           0     0  ...     11        3890           1530
# 9       6560     2.0           0     0  ...      7        1890              0
# 11      6000     1.0           0     0  ...      7         860            300
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 3       1965             0    98136  47.5208 -122.393           1360
# ...

# %%
df.iloc[[0,2,4],[2,3]]
# Out:
#       price  bedrooms
# 0  221900.0         3
# 2  180000.0         2
# 4  510000.0         3

# %%
df=df.set_index('id')# set 'id' column  as the index of the DataFrame
df
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
df.loc[263000018]
# Out:
# date             20140521T000000
# price                   360000.0
# bedrooms                       3
# bathrooms                    2.5
# sqft_living                 1530
# sqft_lot                    1131
# floors                       3.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1530
# sqft_basement                  0
# yr_built                    2009
# yr_renovated                   0
# zipcode                    98103
# lat                      47.6993
# long                    -122.346
# sqft_living15               1530
# sqft_lot15                  1509
# Name: 263000018, dtype: object

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df.price
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[['bedrooms', 'bathrooms']]
# Out:
#             bedrooms  bathrooms
# id
# 7129300520         3       1.00
# 6414100192         3       2.25
# 5631500400         2       1.00
# 2487200875         4       3.00
# 1954400510         3       2.00
# ...              ...        ...
# 263000018          3       2.50
# 6600060120         4       2.50
# 1523300141         2       0.75
# 291310100          3       2.50
# 1523300157         2       0.75
#
# [21613 rows x 2 columns]

# %%
#

# %% [markdown]
# DATA MANIPULATION
# -   to remove columns and rows
# -   to rename columns
# -   to delete missing valuest
# -   to handle missing values
# -   to change the datatype of a column
# -   to count the categorical data

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
cols_to_drop=['sqft_living15', 'sqft_lot15']
df=df.drop(columns=cols_to_drop)
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long'],
#       dtype='object')

# %%
df=df.drop(labels=[7129300529])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5248\714876053.py in ?()
# ----> 1 df=df.drop(labels=[7129300529])
#
# c:\Users\hp\miniconda3\Lib\site-packages\pandas\core\frame.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    5584                 weight  250.0   150.0
#    5585         falcon  speed   320.0   250.0
#    5586                 weight  1.0     0.8
#    5587         """
# -> 5588         return super().drop(
#    5589             labels=labels,
#    5590             axis=axis,
#    5591             index=index,
#
# c:\Users\hp\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, labels, axis, index, columns, level, inplace, errors)
#    4803         obj = self
#    4804
#    4805         for axis, labels in axes.items():
#    4806             if labels is not None:
# ...

# %%
rename={
    'lat':'latu=itu/'[/]'
}
