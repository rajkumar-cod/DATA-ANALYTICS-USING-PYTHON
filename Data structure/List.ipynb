# %% [markdown]
# # Lists in python

# %% [markdown]
# -   Lists are ordered collection of data items.
# -   They store multiple items in a single variable.
# -   List items are separated by commas and enclosed within
# square brackets [].
# -   Lists are changeable meaning we can alter them after creation.
# ### Examples1:

# %%
list1=[1,2,2,3,5,4,6]
list2 = ["Red", "Green", "Blue"]
print(list1) 
print(list2)
# Out:
# [1, 2, 2, 3, 5, 4, 6]
# ['Red', 'Green', 'Blue']

# %%
details = ["Abhijeet", 18, "FYBScIT", 9.8] 
print(details)
# Out:
# ['Abhijeet', 18, 'FYBScIT', 9.8]

# %% [markdown]
# -   As we can see, a single list can contain items of different data types.

# %% [markdown]
# ### List index

# %% [markdown]
# -   Each item/element in a list has its own unique index. This index can
# be used to access any particular item from the list. The first item has
# index [0], second item has index [1], third item has index [2] and so on.
# ### Examples:

# %%
code=["Red","Green","Blue","Yellow","Green"]
# [0]        [1]     [2]        [3]     [4]

# %% [markdown]
# ## Accessing list items

# %% [markdown]
# -   We can access list items by using its index with the square bracket
# syntax [].
# -   For example colors[0] will give “Red”, colors[1] will give
# “Green” and so on…

# %% [markdown]
# ## a. Positive Indexing:
# -   As we have seen that list items have index, as such we can access
# items using these indexes.
# ### Example:

# %%
colors = ["Red", "Green", "Blue", "Yellow", "Green"] 

    #      [0]      [1]     [2]      [3]      [4] 
print(colors[2]) 
print(colors[4]) 
print(colors[0])
# Out:
# Blue
# Green
# Red

# %% [markdown]
# ## b. Negative Indexing:
# -   Similar to positive indexing, negative indexing is also used to access
# items, but from the end of the list.
# -    The last item has index [-1],
# second last item has index [-2], third last item has index [-3] and so
# ### Examples:

# %%
    
    print(Colors[-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(Colors[-1])
#
# NameError: name 'Colors' is not defined

# %% [markdown]
# #### Check whether an item in present in the list?
# -   We can check if a given item is present in the list. This is done
# using the `in` keyword.
# Colors = [“Red”, “Green”, “Blue”, “Yellow”, “Green”]

# %%
if "Yellow"in colors:
    print("true")
else:
    print("false")
# Out:
# true

# %%
if "orange" in colors:
    print("present")
else:
    print("absent")
# Out:
# absent

# %% [markdown]
# # B. Range of Index:
# -   You can print a range of list items by specifying where you want to
# start, where do you want to end and if you want to skip elements in
# between the range.
# ### Syntax:
# listName[start : end : jumpIndex]

# %% [markdown]
# ### Note:
#  -  jump Index is optional. We will see this in later examples.
# ### Examples:
# -    printing elements within a particular range:

# %%
print(colors[1:2])
# Out:
# ['Green']

# %%
print(colors[1:-4])
# Out:
# []

# %%
Animals = ["cat", "dog", "bat", "mouse", "pig", "horse", "donkey", "goat", "cow"]
print(Animals[3:7])
print(Animals[-7:-2])
# Out:
# ['mouse', 'pig', 'horse', 'donkey']
# ['bat', 'mouse', 'pig', 'horse', 'donkey']

# %% [markdown]
#
# Here, we provide index of the element from where we want to start
# and the index of the element till which we want to print the values.
# #### Note:
# -    The element of the end index provided will not be included.
# ### Example:
# -    printing all element from a given index till the end

# %%
print(Animals[4:])
print(Animals[-4:])
# Out:
# ['pig', 'horse', 'donkey', 'goat', 'cow']
# ['horse', 'donkey', 'goat', 'cow']

# %% [markdown]
# ## When no end index is provided, the interpreter prints all the values till the end.
# ## Example:
# -   printing all elements from start to a given index'

# %%
print(Animals[:6])
print(Animals[:-3])
# Out:
# ['cat', 'dog', 'bat', 'mouse', 'pig', 'horse']
# ['cat', 'dog', 'bat', 'mouse', 'pig', 'horse']

# %% [markdown]
# ## When no start index is provided, the interpreter prints all the values from start up to the end index provided.
# ### Example:
# -    Printing alternate values

# %%
print(Animals[::2])
print(Animals[-8:-1:2])
# Out:
# ['cat', 'bat', 'pig', 'donkey', 'cow']
# ['dog', 'mouse', 'horse', 'goat']

# %% [markdown]
# -   Here, we have not provided start and index, which means all the
# values will be considered. But as we have provided a jump index of 2
# only alternate values will be printed.
# ### Example: printing every 3rd consecutive value withing a given

# %%
print(Animals[1:8:3])
# Out:
# ['dog', 'pig', 'goat']

# %% [markdown]
# -   Here, jump index is 3. Hence it prints every 3rd element within given
# index.

# %% [markdown]
# # List Comprehension
# -   list comprehensions are used for creating new lists from other
# iterables like lists, tuples, dictionaries, sets, and even in arrays and
# strings.
# ### Syntax:
# #### List = [Expression(item) for item in iterable if Condition]
# ## Expression:
# -    It is the item which is being iterated.
# ## Iterable:
# -   It can be list, tuples, dictionaries, sets, and even in
# arrays and strings.
# ## Condition:
#  Condition checks if the item should be added to the
# new list or not.
# ### Example : Accepts items with the small letter “o” in the new list

# %%
Names = ["Milo", "Sarah", "Bruno", "Anastasia", "Rosa"] 
namesWith_O = [item for item in Names if "o" in item] 
print(namesWith_O)
# Out:
# ['Milo', 'Bruno', 'Rosa']

# %% [markdown]
# ### Example 2:
# -   Accepts items which have more than 4 letters

# %%
 
namesWith_O = [item for item in Names if (len(item) > 4)] 
print(namesWith_O)
# Out:
# ['Sarah', 'Bruno', 'Anastasia']

# %% [markdown]
# # List Methods
#  ### a.list.sort():
# -   This method sorts the list in ascending order. The original list is updated.
# ### Example 1:

# %%
colors = ["voilet", "indigo", "blue", "green"]
colors.sort()
print(colors)
num=[5,5,6,41,245,511,5]
num.sort()
print(num)
# Out:
# ['blue', 'green', 'indigo', 'voilet']
# [5, 5, 5, 6, 41, 245, 511]

# %% [markdown]
# #### What if you want to print the list in descending order?
# -   We must give reverse=True as a parameter in the sort method.
# ### Examples:

# %%
colors.sort(reverse=True)
print(colors)
num.sort(reverse=True)
print(num)
# Out:
# ['voilet', 'indigo', 'green', 'blue']
# [511, 245, 41, 6, 5, 5, 5]

# %% [markdown]
# #### The reverse parameter is set to False by default.
# ### Note: Do not mistake the reverse parameter with the reverse method.

# %% [markdown]
# ## b. reverse():
# -   This method reverses the order of the list.
# ### Example:

# %%
colors.reverse()
num.reverse()
print(num)
print(colors)
# Out:
# [5, 5, 5, 6, 41, 245, 511]
# ['voilet', 'indigo', 'green', 'blue']

# %% [markdown]
# ## c. Index():
# -   This method returns the index of the first occurrence of the list item.

# %%
print(colors.index("green"))
print(num.index(5))
# Out:
# 2
# 0

# %% [markdown]
# ## d. Count():
# -   Returns the count of the number of items with the given value.
# ### Example:

# %%
colors=["green","greem"]
print(colors.count("green"))
# Out:
# 1

# %% [markdown]
# ## e. Copy()

# %% [markdown]
# -    Returns copy of tge list.
# -   this can be done to perform operation on the list without modifying the original list.

# %%
newlist=colors.copy()
print(colors)
print(newlist)
# Out:
# ['green', 'greem']
# ['green', 'greem']

# %% [markdown]
# ## f. append()
# -   this method appends items to be end of the existing list.
# ### Examples:

# %%
c=['c','d']
c.append("d")
print(c)
# Out:
# ['c', 'd', 'd']

# %% [markdown]
# This method inserts an item at the given index. User has to specify
# index and the item to be inserted within the insert() method.
# Example:
# Colors = [“voilet”, “indigo”, “blue”]
# #
#            [0]        [1]      [2]
# Colors.insert(1, “green”)   #inserts item at index 1
# # updated list: colors = [“voilet”, “green”, “indigo”, “blue”]

# %% [markdown]
# ## g. insert()

# %% [markdown]
# -   This method inserts an item at the given index. User has to specify
# index and the item to be inserted within the insert() method.
# ### Example:

# %%
Colors = ['voilet', 'indigo', 'blue'] 
#
       #    [0]        [1]      [2] 
Colors.insert(1, 'green')   #inserts item at index 1 
# updated list: colors = [“voilet”, “green”, “indigo”, “blue”] 
#       indexs              [0]
print(Colors)
# Out:
# ['voilet', 'green', 'indigo', 'blue']

# %% [markdown]
# ## h. extend():
# -   This method adds an entire list or any other collection datatype (set,
# tuple, dictionary) to the existing list.
# ### Example 1:
# -   add a list to a list

# %%
Rainbow = ['green', 'yellow', 'orange', 'red'] 
Colors.extend(Rainbow)
print(Colors)
# Out:
# ['voilet', 'green', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red']

# %% [markdown]
# ## I.Concatenating two lists:
# -   You can simply concatenate two lists to join two lists.
# ### Example:

# %%
Colors2 = ['yellow', 'orange', 'red'] 
print(Colors + Colors2)
# Out:
# ['voilet', 'green', 'indigo', 'blue', 'green', 'yellow', 'orange', 'red', 'yellow', 'orange', 'red']
