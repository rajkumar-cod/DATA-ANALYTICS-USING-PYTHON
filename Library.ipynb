# %%
import math

# %%
print(math.factorial(5))
print(math.gcd(2,5,7,))
print(math.lcm(2,4,5))
print(math.sin(1))
print(math.tan(0))
print(math.sqrt(16))
# Out:
# 120
# 1
# 20
# 0.8414709848078965
# 0.0
# 4.0

# %%
from random import random, randint,choice,shuffle

# %%
import random

# %%
print("Give number between 0 and 1" ,random.random())
print("Give number between 2 and 8",random.randint(2,5))
print("choose a number from the list",random.choice([2,5,3,7,5,8]))
name=['john', 'jack', 'jane','jill']
shuffle(name)
print('shuffled List:', name)
# Out:
# Give number between 0 and 1 0.3407101698421158
# Give number between 2 and 8 5
# choose a number from the list 7
# shuffled List: ['jill', 'jane', 'john', 'jack']

# %%
from datetime import datetime as dt

# %%
print('Current datetime:', dt.now())
# Out:
# Current datetime: 2025-07-05 18:13:16.794820

# %%
print('Current Date:',dt.now())
print('Current Time',dt.now().time())
# Out:
# Current Date: 2025-07-05 18:15:32.180036
# Current Time 18:15:32.180630

# %%
print('Current year:',dt.now().year)
# Out:
# Current year: 2025

# %%
print("Current Month:",dt.now().month)
# Out:
# Current Month: 7

# %%
print('Current Date:',dt.now().hour)
# Out:
# Current Date: 18

# %%
print("Current minute:",dt.now().minute)
# Out:
# Current minute: 21

# %%
print('Current second:',dt.now().second)
# Out:
# Current second: 19

# %%
print('Current weekday',dt.now().weekday())
print('Current milisecond ',dt.now().microsecond)
date=dt.strftime(dt.now(), '%d/%m/%y')
print(date)
# Out:
# Current weekday 5
# Current milisecond  109402
# 05/07/25
