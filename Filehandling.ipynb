# %%
import os

# %%
print('Current Working Directory is:', os.getcwd())
# Out:
# Current Working Directory is: c:\Users\hp\Desktop\Data analytics using python

# %%
files=os.listdir()
print('Files in Current directory', files)
# Out:
# Files in Current directory ['.git', 'Basics.py', 'Data structure', 'Filehandling.ipynb', 'Functions.ipynb', 'History of python', 'Library.ipynb', 'Operator.ipynb', 'Pattern.py', 'README.md', 'Typecastimg in python.ipynb']

# %%
files=os.listdir()
print('Files in Current directory', files)
