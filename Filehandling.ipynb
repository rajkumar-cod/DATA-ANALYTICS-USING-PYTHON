# %%
import os

# %%
print('Current Working Directory is:', os.getcwd())
#get current working directory
# Out:
# Current Working Directory is: c:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON

# %%
files=os.listdir()
print('Files in Current directory', files)
# Out:
# Files in Current directory ['.git', 'Basics.py', 'Data structure', 'Filehandling.ipynb', 'flask', 'Functions.ipynb', 'History of python', 'Library.ipynb', 'Operator.ipynb', 'Pattern.py', 'python', 'README.md', 'Typecastimg in python.ipynb']

# %%
files=os.listdir()
print('Files in Current  working directory', files)
# Out:
# Files in Current  working directory ['.git', 'Basics.py', 'Data structure', 'Filehandling.ipynb', 'flask', 'Functions.ipynb', 'History of python', 'Library.ipynb', 'Operator.ipynb', 'Pattern.py', 'python', 'README.md', 'Typecastimg in python.ipynb']

# %%
file =os.listdir(r"C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON")
print('Files in current Working directory',  files)
# Out:
# Files in current Working directory ['Basics.py', 'Filehandling.ipynb', 'Functions.ipynb', 'Library.ipynb', 'Operator.ipynb', 'Pattern.py', 'python', 'README.md', 'Typecastimg in python.ipynb']

# %%
total_files=0
for path,folders,files in os.walk(r"C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON"):
    print('=>',path)
    print('📂',folders)
    print('🗄️',files)
    total_files+=len(files)
print('Total files in directory tree:',total_files)
# Out:
# => C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON
# 📂 ['.git', 'Data structure', 'flask', 'History of python']
# 🗄️ ['Basics.py', 'Filehandling.ipynb', 'Functions.ipynb', 'Library.ipynb', 'Operator.ipynb', 'Pattern.py', 'python', 'README.md', 'Typecastimg in python.ipynb']
# => C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON\.git
# 📂 ['hooks', 'info', 'logs', 'objects', 'refs']
# 🗄️ ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index', 'ORIG_HEAD']
# => C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON\.git\hooks
# 📂 []
# 🗄️ ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# => C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON\.git\info
# 📂 []
# 🗄️ ['exclude']
# ...

# %%
files =r'"C:\Users\hp\Desktop\DATA ANALYTICS USING PYTHON"'
if os.path.exists(files):
    print("the files exixts")
else:
    print("not exists")
# Out:
# not exists
