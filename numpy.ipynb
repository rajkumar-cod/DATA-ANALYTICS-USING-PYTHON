# %%
import numpy as np

# %% [markdown]
# # 1 d array

# %%
a=np.array([8,8,55,54,5,])
print(a)
# Out:
# [ 8  8 55 54  5]

# %%
type(a)
# Out:
# numpy.ndarray

# %%
# CREATING 2D ARRAY
a2=np.array([[1,2,3,4,5],[6,6,6,5,7]])
print(a2)
# Out:
# [[1 2 3 4 5]
#  [6 6 6 5 7]]

# %%
# creatinG 3d array
a3=np.array([[[12,3,2],[5,6,8]],[[4,9,9],[4,5,5]]])
print(a3)
# Out:
# [[[12  3  2]
#   [ 5  6  8]]
#
#  [[ 4  9  9]
#   [ 4  5  5]]]

# %%
print(a2.shape)
# Out:
# (2, 5)

# %%
print(a2.ndim)
print(a2.dtype)
# Out:
# 2
# int64

# %%
np.arange(10)
np.arange(1,11)
np.arange(1,11,2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.random.randint(1,11,size=(2,3))
# Out:
# array([[6, 1, 8],
#        [7, 3, 8]], dtype=int32)

# %%
x=np.array([[4,5,5]
            [4,5,6]
            [1,2,3]
            ])
y=np.array([])
