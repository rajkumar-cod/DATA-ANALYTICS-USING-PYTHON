# %% [markdown]
# # What is programming and python?
# ## What is programming?
# -   Programming is way for us to tell the computer what to do.
# -   Computer is a very dumb machine and it only does what we tell it to do.Hence we learn programming and tell computers to do what we are very slow at computation.

# %%
# if i ask you to calculate two number
a=5
b=56
print(a+b)
# Out:
# 61

# %% [markdown]
# ### Question-How about 2352356*5929?

# %% [markdown]
# ## What is python?
# -   support an object oriented programming approach as well as functional programming approach.
# -   python is an interpreted and a high-level programming language.
# -   it was created by Guido Van Rossum in 1989.
# ## Features of python
# -   python is simple and easy to understand.
# -   It is is Interpreted and platform-independent which makes debugging very easy.
# -   python is an open-source programming language.
# -   python provides very big library support. Some of the popular
# libraries include- Numpy,    tensorflow, Selenium, OpenCV, etc.
# -   it is possible to integrate other programming languages within
# python.
# ## What is Python used For?
# -   Python is used in Data Visualization to create plots and Graphical representations.
# -   Python helps in Data Analytics to analyze and understand raw   a data And trends.
# -   It is used in AI and Machine Learning to simulate human  Behavior and to learn  From past data without hard coding.
# -   It is used to create web applications.
# -   It can be used to handle databases.
# -   It is used in business and accounting to perform complex mathematical Operations along with quantitative  and quanlitative  analysis.

# %% [markdown]
# # Modules and pip in Python!
#
# Module is like a code library which can be used to borrow code
# written by somebody else in our python program. There are two
# # Types of modules in python:
# ### Built in Modules
# -   These modules are ready to import and use
# and ships with the python interpreter. There is no need to install
# such modules explicitly.
# ### External Modules
# -   These modules are imported from a third
# party file or can be installed using a package manager like pip or
# conda.
# -   Since this code is written by someone else, we can install
# different versions of a same module with time.
# ### The pip command
# -   It can be used as a package manager
# -   [pip](https://pip.pypa.io/en/stable/) to install a python module.
# -   Lets install a module called pandas using the following command
# ```bash
#    Pip install pandas
#    Using a module in Python (Usage)
#    We use the import syntax to import a module in Python.

# %% [markdown]
# ### Here is an example
# ##### import pandas
# ###### Read and work with a file named ‘words.csv’
# Df = pandas.read_csv(‘words.csv’)
# Print(df)
# -    This will display first few rows from the words.csv file
# #### Our First Program
# -   It will consist of a bunch of print statements.
# -   Print can be used to print something on the console in python.
# -   Write a program to print a poem in Python.

# %%
print("johny johny yes papa" )
# Out:
# johny johny yes papa
